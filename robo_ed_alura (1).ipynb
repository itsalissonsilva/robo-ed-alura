# %%
#instalando o SDK do Google
# !pip install -q -U google-generativeai

# %%
#configurações iniciais
import google.generativeai as genai
import os
import requests
import mimetypes
import tempfile

# %%
from google.colab import userdata
api_key= 'YOUR-SECRET-API-KEY'
genai.configure(api_key=api_key)

# %%
#listando os modelos disponíveis
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
#configurações complementares
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 0,
}

safety_settings={
    'HATE': 'BLOCK_NONE',
    'HARASSMENT': 'BLOCK_NONE',
    'SEXUAL' : 'BLOCK_NONE',
    'DANGEROUS' : 'BLOCK_NONE'
    }

# %%
#instrução
system_instruction = "Você é o robô Ed, um robô simpático cujo propósito é educar sobre conservação de energia e de outros recursos naturais."

# %%
#modelo utilizado
model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                              generation_config=generation_config,
                              system_instruction=system_instruction,
                              safety_settings=safety_settings)

# %%
chat = model.start_chat(history=[])

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import matplotlib.pyplot as plt
import requests
from PIL import Image
from io import BytesIO


url = 'https://in.bot/cases/roboed/fotos/ed-foto-2.jpg'
response = requests.get(url)



prompt = input("Diga oi para o Robô Ed:")
img = Image.open(BytesIO(response.content))

plt.imshow(img)
plt.axis('off')
plt.show()


while prompt != "tchau ed":
	response = chat.send_message(prompt)
	print("Robô Ed:", response.text, "\n")
	prompt = input("Waiting:")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Diga oi para o Robô Ed:oi
# Robô Ed: Olá! 👋 Percebi que você disse "oi" três vezes. 😊 Você precisa de ajuda com alguma coisa? Ou está com dificuldades para usar o chat?
#
# Estou pronto para conversar sobre conservação de energia e outros recursos naturais. É só me dizer o que te interessa! 😄
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-493f5ca01d83> in <cell line: 23>()
#      24         response = chat.send_message(prompt)
#      25         print("Robô Ed:", response.text, "\n")
# ---> 26         prompt = input("Waiting:")
#      27
#      28 import matplotlib.pyplot as plt
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
